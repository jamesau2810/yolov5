# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd drive/MyDrive/

# %%
# !unzip "DrowningDetectionTracking.v2i.yolov5pytorch.zip"
# Helipad https://universe.roboflow.com/project-5yrqo/test_orign
# Drowned people https://universe.roboflow.com/drowningdetection-2zzxz/drowningdetectiontracking

# %%
# %ls

# %%
# import zipfile
# from google.colab import drive

# drive.mount('/content/drive/')
# zip_ref = zipfile.ZipFile("/content/drive/My Drive/DrowningDetectionTracking.v2i.yolov5pytorch.zip", 'r')
# zip_ref.extractall("/tmp/store")
# # zip_ref.close()
# pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="Uh09TRsF7FDY87JKQIfl")
# project = rf.workspace("drowningdetection-2zzxz").project("drowningdetectiontracking")
# version = project.version(2)
# dataset = version.download("yolov5")
# # It download dataset to the current directory which your terminal is in
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting roboflow
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/a3/09/e9211f300c0be75eea2064ef973ac87f17bd49215627116fddf5eee20157/roboflow-1.1.28-py3-none-any.whl.metadata
#   Downloading roboflow-1.1.28-py3-none-any.whl.metadata (9.3 kB)
# Collecting certifi==2023.7.22 (from roboflow)
#   Obtaining dependency information for certifi==2023.7.22 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: chardet==4.0.0 in /usr/lib/python3/dist-packages (from roboflow) (4.0.0)
# Collecting cycler==0.10.0 (from roboflow)
#   Obtaining dependency information for cycler==0.10.0 from https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl.metadata
#   Downloading cycler-0.10.0-py2.py3-none-any.whl.metadata (722 bytes)
# Collecting idna==2.10 (from roboflow)
#   Obtaining dependency information for idna==2.10 from https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl.metadata
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from roboflow) (1.3.2)
# Requirement already satisfied: matplotlib in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (3.6.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Obtaining dependency information for opencv-python-headless==4.8.0.74 from https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (10.0.1)
# Requirement already satisfied: python-dateutil in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (1.26.16)
# Requirement already satisfied: tqdm>=4.41.0 in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (4.64.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/lib/python3/dist-packages (from roboflow) (5.4.1)
# Requirement already satisfied: requests-toolbelt in /home/johnsonhk88/.local/lib/python3.10/site-packages (from roboflow) (0.10.1)
# Collecting python-magic (from roboflow)
#   Obtaining dependency information for python-magic from https://files.pythonhosted.org/packages/6c/73/9f872cb81fc5c3bb48f7227872c28975f998f3e7c2b1c16e95e6432bbb90/python_magic-0.4.27-py2.py3-none-any.whl.metadata
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/johnsonhk88/.local/lib/python3.10/site-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib->roboflow) (4.29.1)
# Requirement already satisfied: packaging>=20.0 in /home/johnsonhk88/.local/lib/python3.10/site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->roboflow) (2.4.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/johnsonhk88/.local/lib/python3.10/site-packages (from requests->roboflow) (2.1.1)
# Downloading roboflow-1.1.28-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.1 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.5 MB/s eta 0:00:00
# Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.7 MB/s eta 0:00:0000:0100:01
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Installing collected packages: python-magic, opencv-python-headless, idna, cycler, certifi, roboflow
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.9.24
#     Uninstalling certifi-2022.9.24:
#       Successfully uninstalled certifi-2022.9.24
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.3 requires opencv-contrib-python, which is not installed.
# pandasai 0.6.4 requires matplotlib<4.0.0,>=3.7.1, but you have matplotlib 3.6.3 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.8.0 which is incompatible.
# tf2onnx 1.12.0 requires flatbuffers~=1.12, but you have flatbuffers 23.5.26 which is incompatible.
# Successfully installed certifi-2023.7.22 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 python-magic-0.4.27 roboflow-1.1.28
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in DrowningDetectionTracking-2 to yolov5pytorch:: 100%|██████████| 1036567/1036567 [00:58<00:00, 17784.56it/s]
# Extracting Dataset Version Zip to DrowningDetectionTracking-2 in yolov5pytorch:: 100%|██████████| 47136/47136 [00:02<00:00, 17628.07it/s]

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Not used here since We already heve the dependency
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16562, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 16562 (delta 20), reused 30 (delta 13), pack-reused 16522
# Receiving objects: 100% (16562/16562), 15.02 MiB | 19.76 MiB/s, done.
# Resolving deltas: 100% (11379/11379), done.

# %%
# You already in the yolov5 dir
# %cd yolov5
# install things in requirements.txt and comet_ml
# %pip install -qr requirements.txt comet_ml  # install
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cp -r DrowningDetectionTracking-2 DrowningDetectionTracking-2
# %cd /DrowningDetectionTracking-2
# Out:
# cp: cannot copy a directory, 'DrowningDetectionTracking-2', into itself, 'DrowningDetectionTracking-2/DrowningDetectionTracking-2'

# %%
# %cd data
# %cp DrowningDetectionTracking-2/data.yaml data.yaml
# %cp /content/drive/MyDrive/DrowningDetectionTracking-2/data.yaml data.yaml # Drown Directory
# %cp /content/drive/MyDrive/test_orign.v2i.yolov5pytorch/data.yaml data.yaml # Helipad Directory
# %cp /content/drive/MyDrive/test_orign.v2i.yolov5pytorch newdata
# %cd ../
# Out:
# /home/johnsonhk88/Documents/yolov5_fyp/yolov5/data
# /home/johnsonhk88/Documents/yolov5_fyp/yolov5

# %%
# !pwd

# %%
# %cd

# %%
# %cd "/content/drive/MyDrive/DrowningDetectionTracking-2/"

# %%
# !mkdir "DrowningDetectionTracking-2"

# %%
# %cd "DrowningDetectionTracking.v2i.yolov5pytorch"

# %%
# %cp -r "/content/DrowningDetectionTracking-2/valid" "valid"

# %%
# %cp -r /content/drive/MyDrive/DrowningDetectionTracking-2 DrowningDetectionTracking-2
# %cp -r /content/drive/MyDrive/DrowningDetectionTracking-2/train train
# %cp -r /content/drive/MyDrive/DrowningDetectionTracking-2/valid valid
# %cp -r /content/drive/MyDrive/test_orign.v2i.yolov5pytorch/train train
# %cp -r /content/drive/MyDrive/test_orign.v2i.yolov5pytorch/valid valid

# %%
# %ls
# Out:
# benchmarks.py                    LICENSE
# CITATION.cff                     models/
# classify/                        nuc_usb_test.py
# CONTRIBUTING.md                  pyproject.toml
# data/                            README.md
# detect_New.py                    README.zh-CN.md
# detect_New_Running.py            requirements.txt
# detect.py                        Rpi_usb_test.py
# detect_SinglelocalImg.py         segment/
# Drone_complete.py                train.py
# DrowningDetectionTracking-2/     Trial002_waypoints.txt
# export.py                        tutorial.ipynb
# FYP_Program_Temp_YOLO_NEW.ipynb  utils/
# hubconf.py                       val.py
# image2video_lib.py               waypt_txt_handle.py
# library.py

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-457-gd7f538e9 Python-3.10.12 torch-2.0.1+cu117 CPU
# Setup complete ✅ (20 CPUs, 30.9 GB RAM, 634.7/915.8 GB disk)

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache
# !python3 train.py --img 640 --batch 16 --epochs 15 --data data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=15, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 37 commits. Use 'git pull ultralytics master' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-457-gd7f538e9 Python-3.10.12 torch-2.0.1+cu117 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET WARNING: Can not parse empty Comet API key
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET WARNING: Can not parse empty Comet API key
# COMET INFO: Using '/home/johnsonhk88/Documents/yolov5_fyp/yolov5/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [05:50<00:00, 42.2kB/s]
#
# Overriding model.yaml nc=80 with nc=7
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     32364  models.yolo.Detect                      [7, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7038508 parameters, 7038508 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /home/johnsonhk88/Documents/yolov5_fyp/yolov5/DrowningDetectionTracking-2/train/labels... 21345 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21345/21345 [00:01<00:00, 16458.64it/s]
# train: New cache created: /home/johnsonhk88/Documents/yolov5_fyp/yolov5/DrowningDetectionTracking-2/train/labels.cache
# train: 24.4GB RAM required, 23.8/30.9GB available, not caching images ⚠️
# val: Scanning /home/johnsonhk88/Documents/yolov5_fyp/yolov5/DrowningDetectionTracking-2/valid/labels... 1215 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1215/1215 [00:00<00:00, 8345.66it/s]
# val: New cache created: /home/johnsonhk88/Documents/yolov5_fyp/yolov5/DrowningDetectionTracking-2/valid/labels.cache
# val: Caching images (1.4GB ram): 100%|██████████| 1215/1215 [00:00<00:00, 1598.49it/s]
#
# AutoAnchor: 4.35 anchors/target, 0.997 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/14         0G     0.1045    0.03321    0.05863         48        640:   8%|▊         | 111/1335 [08:17<1:32:32,  4.54s/it]^C
#        0/14         0G     0.1045    0.03321    0.05863         48        640:   8%|▊         | 111/1335 [08:18<1:31:41,  4.49s/it]
# Traceback (most recent call last):
#   File "/home/johnsonhk88/Documents/yolov5_fyp/yolov5/train.py", line 846, in <module>
#     main(opt)
#   File "/home/johnsonhk88/Documents/yolov5_fyp/yolov5/train.py", line 616, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/home/johnsonhk88/Documents/yolov5_fyp/yolov5/train.py", line 376, in train
#     pred = model(imgs)  # forward
#   File "/home/johnsonhk88/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/johnsonhk88/Documents/yolov5_fyp/yolov5/models/yolo.py", line 244, in forward
#     return self._forward_once(x, profile, visualize)  # single-scale inference, train
#   File "/home/johnsonhk88/Documents/yolov5_fyp/yolov5/models/yolo.py", line 155, in _forward_once
#     x = m(x)  # run
#   File "/home/johnsonhk88/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/johnsonhk88/Documents/yolov5_fyp/yolov5/models/common.py", line 191, in forward
#     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#   File "/home/johnsonhk88/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/johnsonhk88/Documents/yolov5_fyp/yolov5/models/common.py", line 80, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/home/johnsonhk88/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/johnsonhk88/.local/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py", line 171, in forward
#     return F.batch_norm(
#   File "/home/johnsonhk88/.local/lib/python3.10/site-packages/torch/nn/functional.py", line 2450, in batch_norm
#     return torch.batch_norm(
# KeyboardInterrupt
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [12] : (2.7909913063049316, 3.396388292312622)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.04374999999999999
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 5 (486.63 KB)
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %%
# # YOLOv5 PyTorch HUB Inference (DetectionModels only)
# import numpy as np
# import torch
# import torchvision
# import cv2
# # /content/drive/MyDrive/Helipad/train/516heli020_jpg.rf.350ad82d7b07f0fd9dcd0bc49ff1f3a7.jpg
# model = torch.hub.load('ultralytics/yolov5', 'yolov5s', force_reload=True, trust_repo=True)  # or yolov5n - yolov5x6 or custom
# # im = 'https://ultralytics.com/images/zidane.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
# img_file_cv2 = cv2.imread("/content/drive/MyDrive/Helipad/train/516heli020_jpg.rf.350ad82d7b07f0fd9dcd0bc49ff1f3a7.jpg")
# img_A = cv2.cvtColor(img_file_cv2, cv2.COLOR_BGR2RGB)
# img_C = cv2.resize(img_A,(640,640))
# # img_B = torchvision.transforms.ToTensor()(img_C)
# # img = img_B.permute(1,2,0)
# img = img_C
# # img = np.transpose(img_C, (1,2,0))
# # im = 'https://ultralytics.com/images/zidane.jpg'
# device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# # output = model([img.to(device)])
# results = model([img])
# # results = model([img.to(device)])
# # results = model(im)  # inference
# results.print()  # or .show(), .save(), .crop(), .pandas(), etc.

# %%
# results.show()

# %%
# %cd
# %cd /content/yolov5
# Out:
# /root
# /content/yolov5

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/Helipad/train/516heli020_jpg.rf.350ad82d7b07f0fd9dcd0bc49ff1f3a7.jpg

# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/Helipad/train/516heli020_jpg.rf.350ad82d7b07f0fd9dcd0bc49ff1f3a7.jpg
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/DrowningDetectionTracking.v2i.yolov5pytorch/valid/images/110_jpg.rf.d1e6a8e2c03dd76cd8b3c0fcaebe6bde.jpg

# %%
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)

# %%
# %cd ../
# Out:
# /content

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# %cd drive/MyDrive/Helipad
# Out:
# /content/drive/MyDrive/Helipad

# %%
# %cp -r /content/yolov5/runs/train result

# %%
# %cd ../
# %cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/drive/MyDrive/Helipad
